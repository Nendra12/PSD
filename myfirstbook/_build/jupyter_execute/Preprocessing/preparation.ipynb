# %% [markdown]
# # Menghapus Outlier (iris)

# %%
import pandas as pd
from pycaret.anomaly import * 
import matplotlib.pyplot as plt

# load data
data = pd.read_csv("dataset/iris.csv")
data = data.drop(columns=["iris"])

# setup data PyCaret
s = setup(data)

# membuat model dari metode
abod = create_model('abod', fraction=0.05) 
results = assign_model(abod)

# menghapus data outlier
cleaned_data = results[results["Anomaly"] == 0].copy()

print("Data asli: ", results.shape)
print("Data setelah hapus outlier: ", cleaned_data.shape)

# buat file csv baru
cleaned_data.to_csv("iris_ABOD_cleaned.csv", index=False)

fig, axes = plt.subplots(1, 2, figsize=(14,6))

# Sebelum dihapus data outlier
axes[0].scatter(
    results['sepal length'], results['sepal width'],
    c=results['Anomaly'], cmap='coolwarm', edgecolor='k'
)
axes[0].set_title("Sebelum Hapus Outlier (ABOD)")
axes[0].set_xlabel("Sepal Length")
axes[0].set_ylabel("Sepal Width")

# Sesudah dihapus data outlier
axes[1].scatter(
    cleaned_data['sepal length'], cleaned_data['sepal width'],
    c='blue', edgecolor='k'
)
axes[1].set_title("Sesudah Hapus Outlier (ABOD)")
axes[1].set_xlabel("Sepal Length")
axes[1].set_ylabel("Sepal Width")

handles = [
    plt.Line2D([0], [0], marker='o', color='w', label='Normal',
               markerfacecolor='blue', markersize=8),
    plt.Line2D([0], [0], marker='o', color='w', label='Outlier',
               markerfacecolor='red', markersize=8)
]
plt.legend(handles=handles)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from pycaret.anomaly import *
#       3 import matplotlib.pyplot as plt
#       5 # load data
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\anomaly\__init__.py:1
# ----> 1 from pycaret.anomaly.functional import (
#       2     assign_model,
#       3     create_model,
#       4     deploy_model,
#       5     evaluate_model,
#       6     get_config,
#       7     get_current_experiment,
#       8     get_logs,
#       9     load_experiment,
#      10     load_model,
#      11     models,
#      12     plot_model,
#      13     predict_model,
#      14     pull,
#      15     save_experiment,
#      16     save_model,
#      17     set_config,
#      18     set_current_experiment,
#      19     setup,
#      20 )
#      21 from pycaret.anomaly.oop import AnomalyExperiment
#      23 __all__ = [
#      24     "AnomalyExperiment",
#      25     "setup",
#    (...)
#      42     "get_current_experiment",
#      43 ]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\anomaly\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.anomaly.oop import AnomalyExperiment
#       9 from pycaret.loggers.base_logger import BaseLogger
#      10 from pycaret.utils.constants import DATAFRAME_LIKE, SEQUENCE_LIKE
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\anomaly\oop.py:6
#       3 import pandas as pd
#       5 from pycaret.containers.metrics.anomaly import get_all_metric_containers
# ----> 6 from pycaret.containers.models.anomaly import get_all_model_containers
#       7 from pycaret.internal.logging import get_logger
#       8 from pycaret.internal.pycaret_experiment.unsupervised_experiment import (
#       9     _UnsupervisedExperiment,
#      10 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\containers\models\anomaly.py:17
#      15 import pycaret.containers.base_container
#      16 import pycaret.internal.cuml_wrappers
# ---> 17 from pycaret.containers.models.base_model import ModelContainer
#      18 from pycaret.internal.distributions import Distribution
#      19 from pycaret.utils.generic import get_logger, param_grid_to_lists
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\containers\models\base_model.py:9
#       7 from pycaret.containers.base_container import BaseContainer
#       8 from pycaret.internal.distributions import CategoricalDistribution
# ----> 9 from pycaret.internal.pycaret_experiment.pycaret_experiment import _PyCaretExperiment
#      10 from pycaret.utils.generic import get_allowed_engines, get_logger
#      13 class ModelContainer(BaseContainer):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:10
#       7 import cloudpickle
#       8 import pandas as pd
# ---> 10 import pycaret.internal.patches.sklearn
#      11 import pycaret.internal.patches.yellowbrick
#      12 import pycaret.internal.persistence
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\internal\patches\sklearn.py:9
#       6 from sklearn.model_selection._validation import _fit_and_score, _score
#       7 from sklearn.utils import check_random_state
# ----> 9 from pycaret.internal.pipeline import pipeline_predict_inverse_only
#      11 # Monkey patching sklearn.model_selection._search to avoid overflows on windows.
#      12
#      13
#      14 # adapted from https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/utils/_random.pyx
#      15 def _mp_sample_without_replacement(
#      16     n_population: int, n_samples: int, method=None, random_state=None
#      17 ) -> Any:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pycaret\internal\pipeline.py:19
#      17 import sklearn.pipeline
#      18 from sklearn.base import clone
# ---> 19 from sklearn.utils import _print_elapsed_time
#      20 from sklearn.utils.metadata_routing import _routing_enabled
#      21 from sklearn.utils.metaestimators import available_if
#
# ImportError: cannot import name '_print_elapsed_time' from 'sklearn.utils' (C:\Users\USERB-PC\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\__init__.py)
